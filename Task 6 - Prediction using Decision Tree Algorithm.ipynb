# %% [markdown]
# # Name : Piyush Sharma
# # Organisation : The Sparks Foundation
# # Task 6 : Prediction using Decision Tree Algorithm

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split
import seaborn as sns

# %% [markdown]
# ## Reading the file

# %%
data = pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %% [markdown]
# ## Spiltting the data into 2 variables

# %%
y = data['Species']
x=data.drop(['Id','Species'],axis=1)

# %%
# Here we are changing the name of respective species as 1 / 2 / 3 so that model can be applied properly.

# %%
y[y=='Iris-setosa']= 1
y[y=='Iris-versicolor']= 2
y[y=='Iris-virginica']= 3
# Out:
# <ipython-input-43-166623f6c87f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[y=='Iris-setosa']= 1
# <ipython-input-43-166623f6c87f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[y=='Iris-versicolor']= 2
# <ipython-input-43-166623f6c87f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[y=='Iris-virginica']= 3

# %%
#   NOW THE ABOVE SPECIES ARE CHANGED TO : 
#         Iris-setosa  : 1 
#         Iris-versicolor  : 2
#         Iris-virginica  : 3

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 145    3
# 146    3
# 147    3
# 148    3
# 149    3
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# ## Training and testing the data

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.20)

# %% [markdown]
# ## Applying Decision Tree  Algorithm

# %%
dt = DecisionTreeClassifier()
dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ## Predicting the data from model

# %%
y_pred = dt.predict(xtest)
y_pred
# Out:
# array(['1', '1', '1', '2', '2', '2', '1', '3', '1', '3', '1', '1', '3',
#        '3', '3', '2', '3', '2', '1', '1', '2', '2', '1', '3', '2', '3',
#        '2', '2', '3', '2'], dtype=object)

# %%
predicted_data = pd.DataFrame({'Actual result':ytest,'Predicted result':y_pred})
predicted_data
# Out:
#     Actual result Predicted result
# 36              1                1
# 29              1                1
# 48              1                1
# 81              2                2
# 134             3                2
# 78              2                2
# 1               1                1
# 129             3                3
# 23              1                1
# 142             3                3
# 8               1                1
# 35              1                1
# 103             3                3
# 120             3                3
# 137             3                3
# 119             3                2
# 145             3                3
# 73              2                2
# 47              1                1
# 43              1                1
# 68              2                2
# 62              2                2
# 46              1                1
# 108             3                3
# 51              2                2
# 110             3                3
# ...

# %% [markdown]
# ## Visualization of model

# %%
from sklearn import tree
plt.figure(dpi=300)
tree.plot_tree(dt,fontsize=4)
# Out:
# [Text(482.88461538461536, 830.5, 'X[3] <= 0.7\ngini = 0.667\nsamples = 120\nvalue = [40, 41, 39]'),
#  Text(375.5769230769231, 679.5, 'gini = 0.0\nsamples = 40\nvalue = [40, 0, 0]'),
#  Text(590.1923076923077, 679.5, 'X[3] <= 1.65\ngini = 0.5\nsamples = 80\nvalue = [0, 41, 39]'),
#  Text(214.6153846153846, 528.5, 'X[2] <= 5.0\ngini = 0.049\nsamples = 40\nvalue = [0, 39, 1]'),
#  Text(107.3076923076923, 377.5, 'gini = 0.0\nsamples = 38\nvalue = [0, 38, 0]'),
#  Text(321.9230769230769, 377.5, 'X[0] <= 6.15\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(214.6153846153846, 226.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(429.2307692307692, 226.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(965.7692307692307, 528.5, 'X[3] <= 1.75\ngini = 0.095\nsamples = 40\nvalue = [0, 2, 38]'),
#  Text(751.1538461538462, 377.5, 'X[1] <= 2.75\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(643.8461538461538, 226.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
# ...

# %% [markdown]
# ## Confusion matrix and Classification report of model

# %%
from sklearn import metrics

# %%
confusion_matrix = metrics.confusion_matrix(ytest,y_pred)
confusion_matrix
# Out:
# array([[10,  0,  0],
#        [ 0,  9,  0],
#        [ 0,  2,  9]], dtype=int64)

# %%
plt.figure(dpi=120)
sns.heatmap(confusion_matrix,annot=True,cmap=plt.cm.Blues)
plt.title('Heat-map of confusion matrix')
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
# Out:
# Text(56.666666666666664, 0.5, 'Actual values')

# %%
print(metrics.classification_report(ytest,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        10
#            2       0.82      1.00      0.90         9
#            3       1.00      0.82      0.90        11
#
#     accuracy                           0.93        30
#    macro avg       0.94      0.94      0.93        30
# weighted avg       0.95      0.93      0.93        30

# %% [markdown]
# ## Accuracy of model is 93 %
